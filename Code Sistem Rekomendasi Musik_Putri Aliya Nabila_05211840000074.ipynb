# %% [markdown]
# # Spectrogram

# %%
import os
import librosa
import librosa.display
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt

# %%
! pip install pydub

# %%
from pydub import AudioSegment
from IPython.display import Audio
import soundfile as sf

# %%
! pip install pysoundfile

# %% [markdown]
# ## Musik Spectrogram

# %%
 audio_file1 = 'Prelude No. 2.wav'

# %%
ipd.Audio(audio_file1)

# %%
x, sr = librosa.load(audio_file1)
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize = (10, 5))
librosa.display.specshow(Xdb, sr = sr, x_axis = 'time', y_axis = 'hz')
plt.colorbar()

from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas

fig = plt.Figure()
canvas = FigureCanvas(fig)
ax = fig.add_subplot(111)
fig.savefig('Classic1.png')

# %% [markdown]
# #Metode CNN dan CRNN

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import numpy as np

# %%
base_dir = '/content/gdrive/My Drive/CNN/Lima Genre 50/'
# !ls  "/content/gdrive/My Drive/CNN/Lima Genre 50/"
# Out:
# Classic  Folk  Jazz  Pop  Soul	Test  Train

# %%
train_dir = os.path.join(base_dir, 'Train')
validation_dir = os.path.join(base_dir, 'Test')

# %%
classic_dir = os.path.join(base_dir, 'Classic/')
folk_dir = os.path.join(base_dir, 'Folk/')
jazz_dir = os.path.join(base_dir, 'Jazz/')
pop_dir = os.path.join(base_dir, 'Pop/')
soul_dir = os.path.join(base_dir, 'Soul/')

print("Jumlah Data tiap Genre")
print('Jumlah Musik Classic : ', len(os.listdir(classic_dir)))
print('Jumlah Musik Folk : ', len(os.listdir(folk_dir)))
print('Jumlah Musik Jazz : ', len(os.listdir(jazz_dir)))
print('Jumlah Musik Pop : ', len(os.listdir(pop_dir)))
print('Jumlah Musik Soul : ', len(os.listdir(soul_dir)))
# Out:
# Jumlah Data tiap Genre
# Jumlah Musik Classic :  10
# Jumlah Musik Folk :  10
# Jumlah Musik Jazz :  10
# Jumlah Musik Pop :  10
# Jumlah Musik Soul :  10

# %%
train_classic = os.path.join(train_dir, 'classic/')
train_folk = os.path.join(train_dir, 'folk/')
train_jazz = os.path.join(train_dir, 'jazz/')
train_pop = os.path.join(train_dir, 'pop/')
train_soul = os.path.join(train_dir, 'soul/')

# %%
validation_classic = os.path.join(validation_dir, 'classic/')
validation_folk = os.path.join(validation_dir, 'folk/')
validation_jazz = os.path.join(validation_dir, 'jazz/')
validation_pop = os.path.join(validation_dir, 'pop/')
validation_soul = os.path.join(validation_dir, 'soul/')

# %% [markdown]
# Dataset

# %%
import random
from shutil import copyfile

def train_val_split(source, train, val, train_ratio):
  total_size = len(os.listdir(source))
  train_size = int(train_ratio * total_size)
  val_size = total_size - train_size

  randomized = random.sample(os.listdir(source), total_size)
  train_files = randomized[0:train_size]
  val_files = randomized[train_size:total_size]

  for i in train_files:
    i_file = source + i
    destination = train + i
    copyfile(i_file, destination)

  for i in val_files:
    i_file = source +  i
    destination = val + i
    copyfile(i_file, destination)

#jumlah pembagian data training dan testing
train_ratio = 0.9

#pembagian training dan testing
#classic
source_00 = classic_dir
train_00 = train_classic
val_00 = validation_classic
train_val_split(source_00, train_00, val_00, train_ratio)

#pop
source_01 = pop_dir
train_01 = train_pop
val_01 = validation_pop
train_val_split(source_01, train_01, val_01, train_ratio)

#Jazz
source_02 = jazz_dir
train_02 = train_jazz
val_02 = validation_jazz
train_val_split(source_02, train_02, val_02, train_ratio)

#soul
source_03 = soul_dir
train_03 = train_soul
val_03 = validation_soul
train_val_split(source_03, train_03, val_03, train_ratio)

#folk
source_04 = folk_dir
train_04 = train_folk
val_04 = validation_folk
train_val_split(source_04, train_04, val_04, train_ratio)

# %%
print('Jumlah Seluruh Data per Genre  :', len(os.listdir(classic_dir)))
print('Jumlah Train Data per Genre 	:', len(os.listdir(train_classic)))
print('Jumlah Test Data pre Genre     :', len(os.listdir(validation_classic)))
# Out:
# Jumlah Seluruh Data per Genre  : 10
# Jumlah Train Data per Genre 	: 9
# Jumlah Test Data pre Genre     : 1

# %% [markdown]
# Pre processing

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 20,
    horizontal_flip = True,
    shear_range = 0.3,
    fill_mode = 'nearest',
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    zoom_range = 0.2
)

val_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 20,
    horizontal_flip = True,
    shear_range = 0.3,
    fill_mode = 'nearest',
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    zoom_range = 0.2
)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (150, 150),
    batch_size = 5,
    class_mode = 'categorical'
)

val_generator = val_datagen.flow_from_directory(
    validation_dir,
    target_size = (150, 150),
    batch_size = 5,
    class_mode = 'categorical'
)
# Out:
# Found 45 images belonging to 5 classes.
# Found 5 images belonging to 5 classes.

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs = {}):
   if(logs.get('accuracy') > 1):
    print('\nAkurasi mencapai 100%')
    self.model.stop_training = True

callbacks = myCallback()

# %% [markdown]
# Model CNN

# %%
import keras
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3, 3), activation = 'relu', input_shape = (150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation = 'relu'), 
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(200, activation = 'relu'),
    tf.keras.layers.Dropout(0.3,seed=112),
    tf.keras.layers.Dense(500, activation = 'relu'),
    tf.keras.layers.Dropout(0.5,seed=112),
    tf.keras.layers.Dense(5, activation = 'sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 200)               3699400
#
#  dropout (Dropout)           (None, 200)               0
#
#  dense_1 (Dense)             (None, 500)               100500
#
#  dropout_1 (Dropout)         (None, 500)               0
#
#  dense_2 (Dense)             (None, 5)                 2505
#
# =================================================================
# Total params: 3,825,989
# Trainable params: 3,825,989
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Model CNN-GRU

# %%
import keras
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Conv2D, Dense, MaxPooling1D, Flatten, MaxPool2D
import tensorflow as tf
from tensorflow.keras.layers import Dense,Flatten,Conv2D,MaxPooling2D,Dropout,GRU
from tensorflow.keras.models import Sequential

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(16, (3, 3), activation = 'relu', input_shape = (150, 150, 3)),
  tf.keras.layers.Lambda(lambda x: x[:,:,:,0], input_shape=(150, 150, 3)),
  tf.keras.layers.GRU(60, activation="tanh", return_sequences=True),
  tf.keras.layers.GRU(60, activation="tanh", return_sequences=False),
  tf.keras.layers.Dense(30, activation="relu"),
  tf.keras.layers.Dense(10, activation="relu"),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Dense(5, activation = 'sigmoid')
  ])

# %%
model.summary()

# %% [markdown]
# Model Compile & Model Fit

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'Adam', 
              metrics = ['accuracy'])

# %%
history = model.fit(
     train_generator,
     steps_per_epoch = 9, # 45 gambar = batch * steps
     epochs = 50,
     validation_data = val_generator,
     validation_steps = 1, # 5 gambar = batch * steps
     verbose = 1,
     callbacks = [callbacks]
)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 3s 262ms/step - loss: 1.5979 - accuracy: 0.2000 - val_loss: 1.6121 - val_accuracy: 0.2000
# Epoch 2/50
# 9/9 [==============================] - 2s 223ms/step - loss: 1.5231 - accuracy: 0.2222 - val_loss: 1.6122 - val_accuracy: 0.2000
# Epoch 3/50
# 9/9 [==============================] - 2s 180ms/step - loss: 1.5615 - accuracy: 0.2667 - val_loss: 1.6117 - val_accuracy: 0.2000
# Epoch 4/50
# 9/9 [==============================] - 2s 184ms/step - loss: 1.5253 - accuracy: 0.2222 - val_loss: 1.6120 - val_accuracy: 0.2000
# Epoch 5/50
# 9/9 [==============================] - 2s 180ms/step - loss: 1.5333 - accuracy: 0.2667 - val_loss: 1.6118 - val_accuracy: 0.2000
# Epoch 6/50
# 9/9 [==============================] - 2s 195ms/step - loss: 1.5058 - accuracy: 0.2889 - val_loss: 1.6124 - val_accuracy: 0.2000
# Epoch 7/50
# 9/9 [==============================] - 2s 182ms/step - loss: 1.5323 - accuracy: 0.4000 - val_loss: 1.6124 - val_accuracy: 0.2000
# Epoch 8/50
# 9/9 [==============================] - 2s 185ms/step - loss: 1.4805 - accuracy: 0.2889 - val_loss: 1.6126 - val_accuracy: 0.2000
# Epoch 9/50
# 9/9 [==============================] - 2s 184ms/step - loss: 1.5607 - accuracy: 0.1556 - val_loss: 1.6122 - val_accuracy: 0.2000
# Epoch 10/50
# 9/9 [==============================] - 2s 186ms/step - loss: 1.5834 - accuracy: 0.2222 - val_loss: 1.6120 - val_accuracy: 0.2000
# Epoch 11/50
# 9/9 [==============================] - 2s 187ms/step - loss: 1.5417 - accuracy: 0.3111 - val_loss: 1.6122 - val_accuracy: 0.2000
# Epoch 12/50
# 9/9 [==============================] - 2s 181ms/step - loss: 1.5422 - accuracy: 0.2444 - val_loss: 1.6122 - val_accuracy: 0.2000
# Epoch 13/50
# 9/9 [==============================] - 2s 184ms/step - loss: 1.6039 - accuracy: 0.2889 - val_loss: 1.6118 - val_accuracy: 0.2000
# Epoch 14/50
# 9/9 [==============================] - 2s 181ms/step - loss: 1.5531 - accuracy: 0.2222 - val_loss: 1.6122 - val_accuracy: 0.2000
# Epoch 15/50
# 9/9 [==============================] - 2s 185ms/step - loss: 1.5269 - accuracy: 0.2444 - val_loss: 1.6131 - val_accuracy: 0.2000
# Epoch 16/50
# 9/9 [==============================] - 2s 185ms/step - loss: 1.5479 - accuracy: 0.2000 - val_loss: 1.6114 - val_accuracy: 0.2000
# Epoch 17/50
# 9/9 [==============================] - 2s 183ms/step - loss: 1.5610 - accuracy: 0.2222 - val_loss: 1.6111 - val_accuracy: 0.2000
# Epoch 18/50
# 9/9 [==============================] - 2s 184ms/step - loss: 1.5420 - accuracy: 0.2444 - val_loss: 1.6116 - val_accuracy: 0.2000
# Epoch 19/50
# 9/9 [==============================] - 2s 182ms/step - loss: 1.5177 - accuracy: 0.2444 - val_loss: 1.6444 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 9/9 [==============================] - 2s 182ms/step - loss: 1.5607 - accuracy: 0.1556 - val_loss: 1.6111 - val_accuracy: 0.2000
# Epoch 21/50
# 9/9 [==============================] - 2s 184ms/step - loss: 1.5146 - accuracy: 0.1778 - val_loss: 1.6114 - val_accuracy: 0.2000
# Epoch 22/50
# 9/9 [==============================] - 2s 185ms/step - loss: 1.5651 - accuracy: 0.1778 - val_loss: 1.6115 - val_accuracy: 0.2000
# Epoch 23/50
# 9/9 [==============================] - 2s 183ms/step - loss: 1.5212 - accuracy: 0.2222 - val_loss: 1.6116 - val_accuracy: 0.2000
# Epoch 24/50
# 9/9 [==============================] - 2s 187ms/step - loss: 1.5314 - accuracy: 0.2222 - val_loss: 1.5465 - val_accuracy: 0.4000
# Epoch 25/50
# 9/9 [==============================] - 2s 182ms/step - loss: 1.5649 - accuracy: 0.2667 - val_loss: 1.6112 - val_accuracy: 0.2000
# Epoch 26/50
# 9/9 [==============================] - 2s 185ms/step - loss: 1.5178 - accuracy: 0.2667 - val_loss: 1.6112 - val_accuracy: 0.2000
# Epoch 27/50
# 9/9 [==============================] - 2s 187ms/step - loss: 1.4998 - accuracy: 0.2667 - val_loss: 1.6231 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 9/9 [==============================] - 2s 186ms/step - loss: 1.5355 - accuracy: 0.2000 - val_loss: 1.6125 - val_accuracy: 0.2000
# Epoch 29/50
# 9/9 [==============================] - 2s 184ms/step - loss: 1.5580 - accuracy: 0.2444 - val_loss: 1.6123 - val_accuracy: 0.2000
# Epoch 30/50
# 9/9 [==============================] - 2s 184ms/step - loss: 1.4878 - accuracy: 0.3333 - val_loss: 1.6125 - val_accuracy: 0.2000
# Epoch 31/50
# 9/9 [==============================] - 2s 183ms/step - loss: 1.5820 - accuracy: 0.2000 - val_loss: 1.6116 - val_accuracy: 0.2000
# Epoch 32/50
# 9/9 [==============================] - 2s 185ms/step - loss: 1.5624 - accuracy: 0.2889 - val_loss: 1.6120 - val_accuracy: 0.2000
# Epoch 33/50
# 9/9 [==============================] - 2s 187ms/step - loss: 1.5034 - accuracy: 0.3333 - val_loss: 1.6116 - val_accuracy: 0.2000
# Epoch 34/50
# 9/9 [==============================] - 2s 186ms/step - loss: 1.5366 - accuracy: 0.2889 - val_loss: 1.6198 - val_accuracy: 0.2000
# Epoch 35/50
# 9/9 [==============================] - 2s 184ms/step - loss: 1.5449 - accuracy: 0.3111 - val_loss: 1.6140 - val_accuracy: 0.2000
# Epoch 36/50
# 9/9 [==============================] - 2s 185ms/step - loss: 1.5485 - accuracy: 0.2000 - val_loss: 1.6118 - val_accuracy: 0.2000
# Epoch 37/50
# 9/9 [==============================] - 2s 186ms/step - loss: 1.5312 - accuracy: 0.2889 - val_loss: 1.6118 - val_accuracy: 0.2000
# Epoch 38/50
# 9/9 [==============================] - 2s 250ms/step - loss: 1.4966 - accuracy: 0.2222 - val_loss: 1.6129 - val_accuracy: 0.2000
# Epoch 39/50
# 9/9 [==============================] - 2s 186ms/step - loss: 1.5658 - accuracy: 0.2222 - val_loss: 1.6116 - val_accuracy: 0.2000
# Epoch 40/50
# 9/9 [==============================] - 2s 187ms/step - loss: 1.5307 - accuracy: 0.2222 - val_loss: 1.6117 - val_accuracy: 0.2000
# Epoch 41/50
# 9/9 [==============================] - 2s 184ms/step - loss: 1.4877 - accuracy: 0.3111 - val_loss: 1.6118 - val_accuracy: 0.2000
# Epoch 42/50
# 9/9 [==============================] - 2s 185ms/step - loss: 1.5592 - accuracy: 0.1333 - val_loss: 1.6115 - val_accuracy: 0.2000
# Epoch 43/50
# 9/9 [==============================] - 2s 183ms/step - loss: 1.5352 - accuracy: 0.2222 - val_loss: 1.6116 - val_accuracy: 0.2000
# Epoch 44/50
# 9/9 [==============================] - 2s 183ms/step - loss: 1.5108 - accuracy: 0.2667 - val_loss: 1.6122 - val_accuracy: 0.2000
# Epoch 45/50
# 9/9 [==============================] - 2s 183ms/step - loss: 1.5315 - accuracy: 0.2667 - val_loss: 1.6173 - val_accuracy: 0.2000
# Epoch 46/50
# 9/9 [==============================] - 2s 182ms/step - loss: 1.5314 - accuracy: 0.2667 - val_loss: 1.6160 - val_accuracy: 0.2000
# Epoch 47/50
# 9/9 [==============================] - 2s 184ms/step - loss: 1.5017 - accuracy: 0.3333 - val_loss: 1.6125 - val_accuracy: 0.2000
# Epoch 48/50
# 9/9 [==============================] - 2s 184ms/step - loss: 1.5040 - accuracy: 0.2444 - val_loss: 1.6126 - val_accuracy: 0.2000
# Epoch 49/50
# 9/9 [==============================] - 2s 184ms/step - loss: 1.5634 - accuracy: 0.2667 - val_loss: 1.6128 - val_accuracy: 0.2000
# Epoch 50/50
# 9/9 [==============================] - 2s 182ms/step - loss: 1.5618 - accuracy: 0.2222 - val_loss: 1.6125 - val_accuracy: 0.2000

# %%
# %matplotlib inline
import matplotlib.image as mping
import matplotlib.pyplot as plt

scores_train = model.evaluate(train_generator,verbose=1)
scores_validation = model.evaluate(val_generator,verbose=1)
print("Train Accuracy: %.2f%%" % (scores_train[1]*100))
print("Validation Accuracy: %.2f%%" % (scores_validation[1]*100))

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label = 'Training Accuracy')
plt.plot(epochs, val_acc, 'b', label = 'Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.legend(loc = 'best')
plt.show()

plt.plot(epochs, loss, 'r', label = 'Training Loss')
plt.plot(epochs, val_loss, 'b', label = 'Validation Loss')
plt.title('Training and Validation loss')
plt.legend(loc = 'best')
plt.show()
# Out:
# 9/9 [==============================] - 1s 88ms/step - loss: 1.4968 - accuracy: 0.2889
# 1/1 [==============================] - 0s 123ms/step - loss: 1.6125 - accuracy: 0.2000
# Train Accuracy: 28.89%
# Validation Accuracy: 20.00%

# %%
model_weight_file='/content/gdrive/My Drive/CNN/Lima Genre 50/Train'
model.save(model_weight_file)
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/CNN/Lima Genre 50/Train/assets

# %%
from sklearn.metrics import classification_report
from keras.models import load_model
import math
import pandas as pd

val_size = 5
batch_size = 5

compute_steps_per_epoch = lambda x: int(math.ceil(1. * x / batch_size))
test_steps = compute_steps_per_epoch(val_size)


tl_img_aug_cnn = load_model(model_weight_file)
pred=tl_img_aug_cnn.predict(val_generator,
                            verbose=1,
                            steps=test_steps)

predicted_class_indices=np.argmax(pred,axis=1)
labels = (val_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]

filenames=val_generator.filenames
results=pd.DataFrame({"Filename":filenames,
                      "Predictions":predictions})

labels=['classic','pop','jazz','soul','folk']
test_labels = [fn.split('/')[0] for fn in filenames]

cr=classification_report(test_labels, predictions)
class_report=classification_report(test_labels, predictions,
                                   target_names=labels,
                                   output_dict=True)

print(cr)
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0e0d437200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 276ms/step
#               precision    recall  f1-score   support
#
#      classic       0.00      0.00      0.00         1
#         folk       0.00      0.00      0.00         1
#         jazz       0.00      0.00      0.00         1
#          pop       0.20      1.00      0.33         1
#         soul       0.00      0.00      0.00         1
#
#     accuracy                           0.20         5
#    macro avg       0.04      0.20      0.07         5
# weighted avg       0.04      0.20      0.07         5
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Klasifikasi

# %% [markdown]
# Classic

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)
  class_list = os.listdir(train_dir)

  images = np.vstack([x])
  classes = model.predict(images)
  index = np.argmax(classes[0],axis=0)
  print('prediction:', class_list[index])
# Out:
#      <input type="file" id="files-3b1f2d1d-909a-4634-94a0-72f5f085f464" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b1f2d1d-909a-4634-94a0-72f5f085f464">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1.png to 1 (2).png
# prediction: folk

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)
  class_list = os.listdir(train_dir)

  images = np.vstack([x])
  classes = model.predict(images)
  index = np.argmax(classes[0],axis=0)
  print('prediction:', class_list[index])
# Out:
#      <input type="file" id="files-e9314b2d-9921-42d2-a822-0a5885c534c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9314b2d-9921-42d2-a822-0a5885c534c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2.png to 2 (1).png
# prediction: folk

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)
  class_list = os.listdir(train_dir)

  images = np.vstack([x])
  classes = model.predict(images)
  index = np.argmax(classes[0],axis=0)
  print('prediction:', class_list[index])
# Out:
#      <input type="file" id="files-19321051-f5ff-4d82-a478-565a450a1027" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-19321051-f5ff-4d82-a478-565a450a1027">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 3.png to 3 (1).png
# prediction: folk

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-049b8506-40b6-4e1a-9391-d2d052ee44e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-049b8506-40b6-4e1a-9391-d2d052ee44e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 4.png to 4.png
# 4.png
# This image belongs to class folk

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-cedc151e-5b80-4f40-b39b-b0f0ea82b9f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cedc151e-5b80-4f40-b39b-b0f0ea82b9f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 5.png to 5.png
# 5.png
# This image belongs to class folk

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-c8f2d920-696d-41c9-92e7-cabb8b1d2293" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8f2d920-696d-41c9-92e7-cabb8b1d2293">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 6.png to 6.png
# 6.png
# This image belongs to class folk

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-9c1af0d4-018f-4e81-92a8-4a1995434f08" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c1af0d4-018f-4e81-92a8-4a1995434f08">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 7.png to 7.png
# 7.png
# This image belongs to class folk

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-c9345cad-ec77-4066-a128-756fb9a9868b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9345cad-ec77-4066-a128-756fb9a9868b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 10.png to 10.png
# 10.png
# This image belongs to class folk

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-46803891-3ece-42d1-9e9b-0fd0d973f03b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46803891-3ece-42d1-9e9b-0fd0d973f03b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 9.png to 9.png
# 9.png
# This image belongs to class folk

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-f64bec94-475a-45b4-b46a-5d522f3e5ce2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f64bec94-475a-45b4-b46a-5d522f3e5ce2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 8.png to 8 (4).png
# 8.png
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-76-0d990b49c137> in <module>()
#      22
#      23   for j in range(42):
# ---> 24     if classes[0][j] == 1. :
#      25       print('This image belongs to class', class_list[j-1])
#      26       break
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %% [markdown]
# Pop

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-5b46af0d-3b03-424b-97b5-42384c3cd7c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5b46af0d-3b03-424b-97b5-42384c3cd7c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 11.png to 11.png
# 11.png
# This image belongs to class classic

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-a0232a62-59ff-4b49-8225-feb41491bead" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a0232a62-59ff-4b49-8225-feb41491bead">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 12.png to 12.png
# 12.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-51b49aa9-e7e3-467b-9c09-6dd560ff0ccb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-51b49aa9-e7e3-467b-9c09-6dd560ff0ccb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 13.png to 13.png
# 13.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-a0e974da-65d6-43f9-a18f-2dcdcdba7794" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a0e974da-65d6-43f9-a18f-2dcdcdba7794">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 14.png to 14.png
# 14.png
# This image belongs to class classic

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-c770c763-a752-413e-a1fd-43c624191500" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c770c763-a752-413e-a1fd-43c624191500">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 15.png to 15.png
# 15.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-f0c790f2-a390-486d-8412-98c4106acd20" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0c790f2-a390-486d-8412-98c4106acd20">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 16.png to 16.png
# 16.png
# This image belongs to class classic

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-47a34328-7a87-44d8-8ff6-489d88a6bc04" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-47a34328-7a87-44d8-8ff6-489d88a6bc04">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 17.png to 17.png
# 17.png
# This image belongs to class classic

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-8e415a14-8e22-4666-b67c-4426a00278a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8e415a14-8e22-4666-b67c-4426a00278a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 18.png to 18.png
# 18.png
# This image belongs to class classic

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-20e2a4ea-a106-4cc4-8839-d1714f41ea80" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-20e2a4ea-a106-4cc4-8839-d1714f41ea80">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 19.png to 19.png
# 19.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-83c3a453-02c6-4bd4-9461-3af628d10c6d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-83c3a453-02c6-4bd4-9461-3af628d10c6d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 20.png to 20.png
# 20.png
# This image belongs to class classic

# %% [markdown]
# Jazz

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-e82d5487-0b23-45eb-85c9-072a868a05ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e82d5487-0b23-45eb-85c9-072a868a05ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 21.png to 21.png
# 21.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-4010ca88-d5f8-409c-9ac4-29ada46c06a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4010ca88-d5f8-409c-9ac4-29ada46c06a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 22.png to 22.png
# 22.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-9ac8bd72-0b57-4759-b148-19331100c36d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ac8bd72-0b57-4759-b148-19331100c36d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 23.png to 23.png
# 23.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-a060e3ef-fecb-4c20-b7cc-eeb47ff61816" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a060e3ef-fecb-4c20-b7cc-eeb47ff61816">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 24.png to 24.png
# 24.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-33fc1a28-187d-4e2d-ac06-4c0cb861cbbf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33fc1a28-187d-4e2d-ac06-4c0cb861cbbf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 25.png to 25.png
# 25.png
# This image belongs to class classic

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-d6da7eda-afbd-4b38-b1a4-77029faf55ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6da7eda-afbd-4b38-b1a4-77029faf55ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 26.png to 26.png
# 26.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-d7841378-d4f7-4017-b65a-efbf26533a5a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d7841378-d4f7-4017-b65a-efbf26533a5a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 27.png to 27.png
# 27.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-1a82b307-b2f5-4e75-ae14-e205d590af79" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a82b307-b2f5-4e75-ae14-e205d590af79">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 28.png to 28.png
# 28.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-dfe0ef5f-49b7-4106-ab79-82b760c1383e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dfe0ef5f-49b7-4106-ab79-82b760c1383e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 29.png to 29.png
# 29.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-50255565-a052-47c4-9147-75e27676e069" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50255565-a052-47c4-9147-75e27676e069">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 30.png to 30.png
# 30.png
# This image belongs to class soul

# %% [markdown]
# Soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-08eca6ea-173b-4d61-8db8-de0152474c4f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08eca6ea-173b-4d61-8db8-de0152474c4f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 31.png to 31.png
# 31.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-ae9dabef-6a18-4277-a57e-9bad97633af9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae9dabef-6a18-4277-a57e-9bad97633af9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 32.png to 32.png
# 32.png
# This image belongs to class classic

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-c736d166-6a46-4b91-ada1-0f2b2d4b8374" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c736d166-6a46-4b91-ada1-0f2b2d4b8374">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 33.png to 33.png
# 33.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-6482107e-7d4b-4a43-9394-758955f78892" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6482107e-7d4b-4a43-9394-758955f78892">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 34.png to 34.png
# 34.png
# This image belongs to class classic

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-136fc007-8ca9-467e-9ca1-6720d3e676ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-136fc007-8ca9-467e-9ca1-6720d3e676ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 35.png to 35.png
# 35.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-3b08e7f5-2ae3-4a3f-9c29-0b4b5d4ec23b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b08e7f5-2ae3-4a3f-9c29-0b4b5d4ec23b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 36.png to 36.png
# 36.png
# This image belongs to class classic

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-29edc22c-4a72-4951-96b5-e818cfad5851" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-29edc22c-4a72-4951-96b5-e818cfad5851">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 37.png to 37.png
# 37.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-4b7bbb58-1948-40e0-a792-ea6c3313aea4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4b7bbb58-1948-40e0-a792-ea6c3313aea4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 38.png to 38.png
# 38.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-75a580d4-a0b3-4378-a0d1-1bb39baf820a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-75a580d4-a0b3-4378-a0d1-1bb39baf820a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 39.png to 39.png
# 39.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-88d84a40-ef98-47a3-9e6f-494546bfcdd0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88d84a40-ef98-47a3-9e6f-494546bfcdd0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 40.png to 40.png
# 40.png
# This image belongs to class classic

# %% [markdown]
# Folk

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-8024959e-d448-4c79-a14d-57adbf1a7185" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8024959e-d448-4c79-a14d-57adbf1a7185">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 41.png to 41.png
# 41.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-a180ff68-b203-46a0-872f-5ca340df65d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a180ff68-b203-46a0-872f-5ca340df65d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 42.png to 42.png
# 42.png
# This image belongs to class pop

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-c9410572-0f41-4290-b50b-ccc20e2bd194" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9410572-0f41-4290-b50b-ccc20e2bd194">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 43.png to 43.png
# 43.png
# This image belongs to class folk

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-257e7d6c-a9e9-46bc-99d5-9b5d806204fb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-257e7d6c-a9e9-46bc-99d5-9b5d806204fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 44.png to 44.png
# 44.png
# This image belongs to class pop

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-0ef0ec8e-3d9f-40d7-8187-f2f33fecbcc4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ef0ec8e-3d9f-40d7-8187-f2f33fecbcc4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 45.png to 45.png
# 45.png
# This image belongs to class soul

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-0c2e547f-7b0d-4b75-90e1-e20850d6e406" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c2e547f-7b0d-4b75-90e1-e20850d6e406">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 46.png to 46.png
# 46.png
# This image belongs to class folk

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-842bc13d-7ca0-4394-996b-bbb8ee1bc293" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-842bc13d-7ca0-4394-996b-bbb8ee1bc293">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 47.png to 47.png
# 47.png
# This image belongs to class classic

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-424288f9-06aa-427d-941d-8256b543cc2c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-424288f9-06aa-427d-941d-8256b543cc2c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 48.png to 48.png
# 48.png
# This image belongs to class classic

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-9d591cab-714a-4315-a2af-502d6e2834d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d591cab-714a-4315-a2af-502d6e2834d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 49.png to 49.png
# 49.png
# This image belongs to class classic

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  #predicting images
  path = fn
  img = image.load_img(path, target_size = (150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 5)

  print(fn)

  class_list = os.listdir(train_dir)

  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j-1])
      break
# Out:
#      <input type="file" id="files-8ea84a85-b445-4cd3-b523-6c493d5697a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8ea84a85-b445-4cd3-b523-6c493d5697a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 50.png to 50.png
# 50.png
# This image belongs to class soul
